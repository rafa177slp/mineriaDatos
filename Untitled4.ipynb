# %% [markdown]
# <a href="https://colab.research.google.com/github/rafa177slp/mineriaDatos/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###Conceptos

# %% [markdown]
# ##Mineria de datos

# %% [markdown]
# ####ciencia de datos
