# %% [markdown]
# <a href="https://colab.research.google.com/github/jesusrevilla/mineria-de-datos/blob/main/Miner%C3%ADa_de_Datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Minería de Datos

# %% [markdown]
# ## Primer parcial

# %% [markdown]
# ### Introducción

# %% [markdown]
# #### Conceptos

# %% [markdown]
# #### Ciencia de Datos

# %% [markdown]
# Help and Documentation in IPython

# %%
# La funcion help nos muestra la ayuda
help(len)
# Out:
# Help on built-in function len in module builtins:
#
# len(obj, /)
#     Return the number of items in a container.

# %%
# Otra forma de obtener ayuda es utilizando ?
len?

# %%
# Ejemplo de ayuda en una lista
L = [1, 2, 3]
L.insert?

# %%
# Otro ejemplo de ayuda
L?

# %%
# Ejemplo con una función con Docstring
def square(a):
    """Return the square of a."""
    return a ** 2

# %%
help(square)
# Out:
# Help on function square in module __main__:
#
# square(a)
#     Return the square of a.

# %%
# Ejemplo de ayuda de funcion personalizada
square??

# %%
len??

# %%
L.insert

# %%
from itertools import combinations
